# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv("/kaggle/input/test-file/tested.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
  df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df['Embarked'].value_counts()
# Out:
# S    270
# C    102
# Q     46
# Name: Embarked, dtype: int64

# %%
df['Embarked'].fillna('S', inplace=True)

# %%
df['SibSp'].value_counts()
# Out:
# 0    283
# 1    110
# 2     14
# 3      4
# 4      4
# 8      2
# 5      1
# Name: SibSp, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# 0    324
# 1     52
# 2     33
# 3      3
# 4      2
# 9      2
# 6      1
# 5      1
# Name: Parch, dtype: int64

# %%
df['Survived'] = df['Survived'].astype('category')
df['Pclass'] = df['Pclass'].astype('category')
df['Sex'] = df['Sex'].astype('category')
df['Age'] = df['Age'].astype('category')
df['Embarked'] = df['Embarked'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    category
#  2   Pclass       418 non-null    category
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    category
#  5   Age          418 non-null    category
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    category
# dtypes: category(5), float64(1), int64(3), object(3)
# memory usage: 28.2+ KB

# %%
df.describe()
# Out:
#        PassengerId       SibSp       Parch        Fare
# count   418.000000  418.000000  418.000000  417.000000
# mean   1100.500000    0.447368    0.392344   35.627188
# std     120.810458    0.896760    0.981429   55.907576
# min     892.000000    0.000000    0.000000    0.000000
# 25%     996.250000    0.000000    0.000000    7.895800
# 50%    1100.500000    0.000000    0.000000   14.454200
# 75%    1204.750000    1.000000    0.000000   31.500000
# max    1309.000000    8.000000    9.000000  512.329200

# %%
sns.countplot(data=df, x='Survived')
death_percent = round((df['Survived'].value_counts().values[0]/417)*100)
print('out of {} people died in the accident'.format(death_percent))
# Out:
# out of 64 people died in the accident

# %%
print((df['Pclass'].value_counts()/417)*100)
sns.countplot(data=df, x='Pclass')
plt.show
# Out:
# 3    52.278177
# 1    25.659472
# 2    22.302158
# Name: Pclass, dtype: float64
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data=df, x='Sex')
print((df['Sex'].value_counts()/417)*100)
# Out:
# male      63.788969
# female    36.450839
# Name: Sex, dtype: float64

# %%
sns.countplot(data=df, x='SibSp')
print((df['SibSp'].value_counts()/417)*100)
# Out:
# 0    67.865707
# 1    26.378897
# 2     3.357314
# 3     0.959233
# 4     0.959233
# 8     0.479616
# 5     0.239808
# Name: SibSp, dtype: float64

# %%
sns.countplot(data=df, x='Parch')
print((df['Parch'].value_counts()/417)*100)
# Out:
# 0    77.697842
# 1    12.470024
# 2     7.913669
# 3     0.719424
# 4     0.479616
# 9     0.479616
# 6     0.239808
# 5     0.239808
# Name: Parch, dtype: float64

# %%
sns.countplot(data=df, x='Embarked')
print((df['Embarked'].value_counts()/417)*100)
# Out:
# S    64.748201
# C    24.460432
# Q    11.031175
# Name: Embarked, dtype: float64

# %%
sns.distplot(df['Age'])
plt.show()
# Out:
# /tmp/ipykernel_32/1599895865.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

print("people with age btw 60 and 70 ", df[(df['Age'] > 60) & (df['Age'] < 70)].shape[0])
print("people with age btw 70 and 75 ", df[df['Age'] > 75].shape[0])
print("people with age btw 70 and 75 ", df[(df['Age'] >= 70) & (df['Age'] <= 70)].shape[0])
# Out:
# people with age btw 60 and 70  10
# people with age btw 70 and 75  1
# people with age btw 70 and 75  0

# %%
sns.displot(df['Fare'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
print(df['Fare'].skew())
print(df['Fare'].kurt())
# Out:
# 3.6872133081121405
# 17.92159525773599

# %%
print("people with fare btw 200 and 300 ", df[(df['Fare'] >200) & (df['Age'] < 300)].shape[0])
print("people with fare greater than $300 ", df[df['Fare'] >300].shape[0])
# Out:
# people with fare btw 200 and 300  18
# people with fare greater than $300  1

# %%
sns.countplot(x='Survived', hue='Pclass',data=df)
pd.crosstab(df['Pclass'], df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Pclass
# 1         53.3  46.7
# 2         67.7  32.3
# 3         67.0  33.0

# %%
sns.countplot(x='Survived', hue='Sex',data=df)
pd.crosstab(df['Sex'], df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived      0      1
# Sex
# female      0.0  100.0
# male      100.0    0.0

# %%
sns.countplot(x='Survived', hue='Embarked',data=df)
pd.crosstab(df['Embarked'], df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Embarked
# C         60.8  39.2
# Q         47.8  52.2
# S         67.4  32.6

# %%
plt.figure(figsize=(15,6))
sns.displot(df[df['Survived'] == 0]['Age'])
sns.displot(df[df['Survived'] == 1]['Age'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
grid = sns.FacetGrid(df, col='Survived', height=6)

# Use displot on each facet
grid.map_dataframe(sns.histplot, x='Age', bins=20, kde=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
