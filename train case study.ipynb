# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = pd.read_csv(r"C:\Users\Lenovo\Desktop\juypternotebooks files\train.csv")
file.head()
# Out:
#    Passenger id  survived  Pclass  \
# 0             0         0       3
# 1             1         1       1
# 2             2         1       3
# 3             3         1       1
# 4             4         0       3
#
#                                                 Name     Sex   Age  SibSP  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked
# 0      0   7.2500        S
# 1      0  71.2833        C
# 2      0   7.9250        S
# 3      0  53.1000        S
# 4      0   8.0500        S

# %%
avg_mean = file['Age'].mean()
file["Age"].fillna(value=avg_mean , inplace=True)
file
# Out:
#      Passenger id  survived  Pclass  \
# 0               0         0       3
# 1               1         1       1
# 2               2         1       3
# 3               3         1       1
# 4               4         0       3
# ..            ...       ...     ...
# 886           886         0       2
# 887           887         1       1
# 888           888         0       3
# 889           889         1       1
# 890           890         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
male_age_mean = file[file['Sex'] == 'male']['Age'].mean()
male_age_mean
# Out:
# 30.505824243042102

# %%
labels = ['male', 'female']

plt.pie(file['Sex'].value_counts(), labels = ['male', 'female'], autopct='%1.1f%%', startangle=140)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
female_age_mean = file[file['Sex'] == 'female']['Age'].mean()
female_age_mean
# Out:
# 28.21673004870738

# %%
file['survived'].mean()
# Out:
# 0.3838383838383838

# %%
data.loc["Moran, Mr. James","Age"]
# Out:
# 29.69911764705882

# %%
data.loc['Fynney, Mr. Joseph J':'Beesley, Mr. Lawrence']
# Out:
#                        PassengerId  Survived  Pclass   Sex   Age  SibSp  \
# Name
# Fynney, Mr. Joseph J            21         0       2  male  35.0      0
# Beesley, Mr. Lawrence           22         1       2  male  34.0      0
#
#                        Parch  Fare Embarked
# Name
# Fynney, Mr. Joseph J       0  26.0        S
# Beesley, Mr. Lawrence      0  13.0        S

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
file.describe()
# Out:
#        Passenger id    survived      Pclass         Age       SibSP  \
# count    891.000000  891.000000  891.000000  714.000000  891.000000
# mean     445.000000    0.383838    2.308642   29.699118    0.523008
# std      257.353842    0.486592    0.836071   14.526497    1.102743
# min        0.000000    0.000000    1.000000    0.420000    0.000000
# 25%      222.500000    0.000000    2.000000   20.125000    0.000000
# 50%      445.000000    0.000000    3.000000   28.000000    0.000000
# 75%      667.500000    1.000000    3.000000   38.000000    1.000000
# max      890.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
